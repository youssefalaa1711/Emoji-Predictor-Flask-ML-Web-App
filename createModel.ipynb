# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
from sklearn import tree


emoji_data = pd.read_csv("refined_emojiData.csv")
emoji_data
# Out:
#     age  gender emoji
# 0    23       1     👨
# 1    25       0     👩
# 2    26       1     👨
# 3    29       1     👨
# 4    30       1     👨
# 5    31       1     👨
# 6    33       1     👨
# 7    37       1     👨
# 8    20       0     👩
# 9    21       0     👩
# 10   25       1     👨
# 11   26       0     👩
# 12   25       0     👩
# 13   27       0     👩
# 14   20       0     👩
# 15   30       1     👨
# 16   31       0     👩
# 17   34       1     👨
# 18   35       0     👩
# 19   11       0     👧
# 20   20       1     👨
# 21   15       1     👦
# 22   17       1     👦
# 23   18       0     👧
# 24   11       0     👧
# 25   15       0     👧
# 26   16       1     👦
# 27   15       0     👧
# 28   19       1     👨
# 29    5       1     👦
# 30   17       0     👧
# 31   35       1     👨
# 32   62       0     👵
# 33   70       1     🧓
# 34   45       0     👩
# 35   12       1     👦
# 36   20       0     👩

# %%
#Split to train model
X= emoji_data.drop(columns="emoji")
y=emoji_data['emoji']

#train data
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model =DecisionTreeClassifier()
model.fit(X_train,y_train)

prediction = model.predict([[100, 1]])
prediction
# Out:
# c:\Users\youss\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['🧓'], dtype=object)

# %%
prediction1 = model.predict(X_test)

score =accuracy_score(y_test,prediction1)
score
# Out:
# 1.0

# %%
joblib.dump(model, "emoji_predictor.joblib")
# Out:
# ['emoji_predictor.joblib']
